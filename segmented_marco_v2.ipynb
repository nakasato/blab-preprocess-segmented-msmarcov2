# %%
import os
import json
import pandas as pd
import random
from tqdm import tqdm

# %%
def prep_ft_input(df,
                  output_folder,
                  prop={'train': 0.8, 'val': 0.1, 'test': 0.1}, 
                  sample_size=5000):
    
    assert sum(list(prop.values())) == 1, 'The proportions do not add up to 1.'
    
    df = df.sample(n=sample_size, random_state=7)
    
    n_train = int(prop['train'] * len(df))
    n_val = int(prop['val'] * len(df))
    n_test = len(df) - n_train - n_val

    train = df[:n_train]
    val = df[n_train:n_train+n_val]
    test = df[n_train+n_val:len(df)]
    
    print('Train dataset size:', len(train))
    print('Validation dataset size:', len(val))
    print('Test dataset size:', len(test))
    
    train['question'].to_csv(output_folder + 'train.source', header=False, index=False)
    val['question'].to_csv(output_folder + 'val.source', header=False, index=False)
    test['question'].to_csv(output_folder + 'test.source', header=False, index=False)
    
    train['answer'].to_csv(output_folder + 'train.target', header=False, index=False)
    val['answer'].to_csv(output_folder + 'val.target', header=False, index=False)
    test['answer'].to_csv(output_folder + 'test.target', header=False, index=False)
    
    return train, val, test

# %%
qa_corpora = pd.read_json('segmented_msmarco_v2/squad.biomedical.train.json', orient='split')
print(len(qa_corpora))
qa_corpora.head()
# Out:
# 22134
#                                           paragraphs
# 0  [{'context': 'Chronic Obstructive Pulmonary Di...
# 1  [{'context': 'Folic acid is the synthetic form...
# 2  [{'context': 'So which minerals do you need, a...
# 3  [{'context': 'A triglyceride is an ester deriv...
# 4  [{'context': 'What causes tooth root resorptio...

# %%
# Convert each string entry in qa_corpora to a dictionary for parsing
qa_data = []
for i, row in tqdm(qa_corpora.iterrows()):
    item = {}
    item['question'] = row['paragraphs'][0]['qas'][0]['question']
    item['answer'] = row['paragraphs'][0]['qas'][0]['answers'][0]['text']

    qa_data.append(item)
# Out:
# 22134it [00:02, 10604.12it/s]

# %%
df = pd.DataFrame(qa_data)
df.replace({'"': '', '\n': ' ', '\t': ''}, regex=True, inplace=True)

print(len(df))
df.head()
# Out:
# 22134
#                              question  \
# 0             what disability is copd
# 1             what does folic acid do
# 2  the importance of minerals in diet
# 3         triglycerides what are they
# 4     what causes resorption of teeth
#
#                                               answer
# 0  Chronic Obstructive Pulmonary Disease and Soci...
# 1  crucial for proper brain function and plays an...
# 2  Minerals are incredibly important for health a...
# 3  A triglyceride is an ester derived from glycer...
# 4  trauma, periodontitis, orthodontic treatment, ...

# %%
train, val, test = prep_ft_input(df, output_folder='input_rag_ft/', sample_size=3000)
# Out:
# Train dataset size: 2400
# Validation dataset size: 300
# Test dataset size: 300

# %%
# Deleting any double quotes in every file generated
inp = 'input_rag_ft/'
out = 'finetune_qa_pairs_processed/'

files = os.listdir(inp)

for f in files:
    with open(os.path.join(inp, f), 'r') as fi, open(os.path.join(out, f), 'w') as fo:
        for line in fi:
            fo.write(line.replace('"', ''))

# %% [markdown]
# ## Generating samples for qualitative evals

# %%
sample_train = train[['question', 'answer']].head(20).to_dict('records')
sample_train
# Out:
# [{'question': 'what is ivig used to treat?',
#   'answer': 'autoimmune diseases, immune deficiencies, and certain kinds of infections.'},
#  {'question': 'process of recovery after a leg fracture',
#   'answer': 'Give your fracture time to heal. Your body needs time to mend itself and create new bone; a fracture generally takes between 6 and 12 weeks to heal substantially. When healing, your bone will go through three stages: Inflammation: This process lasts for the first few days after a fracture.'},
#  {'question': 'causes of left side chest pain',
#   'answer': 'cardiovascular conditions like angina, a heart attack, pericarditis, pulmonary embolism or aortic dissection.'},
#  {'question': 'what is fistula',
#   'answer': 'an abnormal connection between two parts inside of the body.'},
#  {'question': 'what is ptsd mean',
#   'answer': "a mental health condition that's triggered by a terrifying event — either experiencing it or witnessing it."},
#  {'question': 'causes of defatting skin',
#   'answer': 'whitening and drying of the skin which may result in cracking, secondary infection and chemical irritant contact dermatitis.'},
#  {'question': 'what are the treatments for sleep apnea',
#   'answer': 'nasal surgery, palate surgery (including uvulopalatopharyngoplasty [UPPP]), upper airway stimulation therapy, tongue reduction surgery, genioglossus advancement, maxillo-mandibular advancement, tracheostomy, and bariatric surgery.'},
#  {'question': 'what is considered a negative tb',
#   'answer': 'A negative reaction usually means you have never been infected with the bacteria that cause TB.'},
#  {'question': 'what are stribild tablets?',
#   'answer': 'STRIBILD is a fixed-dose combination tablet containing elvitegravir, cobicistat, emtricitabine, and tenofovir DF for oral administration.'},
#  {'question': 'what is rituxan used for', 'answer': 'rheumatoid arthritis'},
#  {'question': 'how long does flu take to show symptoms',
#   'answer': 'Flu symptoms usually start within one to four days after infection.'},
#  {'question': 'what is dental prosthetic service',
#   'answer': 'The dental specialty dealing with the needs of patients with missing teeth or with abnormal maxillofacial or oral structures.'},
#  {'question': 'how long can it take before hiv symptoms are detected',
#   'answer': '3 to 4 weeks'},
#  {'question': 'how long does kidney dialysis last',
#   'answer': 'three to four hours'},
#  {'question': 'symptoms of bipartite patella',
#   'answer': 'pain directly over the kneecap and swelling overthe fibrous part.'},
#  {'question': 'what does a pulse oximeter monitor',
#   'answer': 'Pulse Oximeter is a very advantageous device for each person as by using this device you can keep monitor oxygen saturation level in your blood.'},
#  {'question': 'what determines if a client will develop aids from an hiv infection?',
#   'answer': 'the virus attacks and weakens the immune system. As the immune system weakens, the person is at risk of getting life-threatening infections and cancers. When that happens, the illness is called AIDS.'},
#  {'question': 'what organelle stores food, water, and waste',
#   'answer': 'vacuole'},
#  {'question': 'how long does percocet stay in your system',
#   'answer': 'approximately 2 days'},
#  {'question': 'what causes fatigue & back pain',
#   'answer': 'pyelonephritis or reflux of urine from bladder to kidney or combination of both.'}]

# %%
sample_test = test[['question', 'answer']].head(20).to_dict('records')
sample_test
# Out:
# [{'question': 'maximum dose of abilify for children',
#   'answer': '2 mg once daily'},
#  {'question': 'what is translocation mutation',
#   'answer': 'Chromosomal translocation, that is a chromosomal segment is moved from one position to another, either within the same chromosome or to another chromosome.'},
#  {'question': 'what are some bad things that can happen when having a genetic squencing done',
#   'answer': "sequencing the genome doesn't immediately lay open the genetic secrets of an entire species. Even with a rough draft of the human genome sequence in hand, much work remains to be done."},
#  {'question': 'idiopathic meaning g', 'answer': 'the cause is not known'},
#  {'question': 'what is the pituitary gland',
#   'answer': 'a pea-sized gland at the base of the brain, produces a number of hormones.'},
#  {'question': 'how do lipids function',
#   'answer': 'functions of lipids include storing energy, signaling, and acting as structural components of cell membranes.'},
#  {'question': 'which system causes diabetes', 'answer': 'immune system'},
#  {'question': 'what is the molecule that gives plants rigidity',
#   'answer': 'the cell wall'},
#  {'question': 'where is lymph contained',
#   'answer': 'Lymph nodes are usually present in clusters in the armpits, on either side of the neck, and in the groin.'},
#  {'question': 'where is the pancreas located relative to other organs',
#   'answer': 'behind the stomach and is surrounded by other organs, including the spleen, liver and small intestine.'},
#  {'question': 'which bacteria cause pink eye',
#   'answer': 'pyogenic (pus-producing) bacteria'},
#  {'question': 'what does pfo mean in medical terms',
#   'answer': 'a defect in the septum (wall) between the two upper (atrial) chambers of the heart.'},
#  {'question': 'define angioma of the skin',
#   'answer': 'a skin disease marked by minute vascular points arranged in rings on the skin.'},
#  {'question': "what happens when you don't eat enough",
#   'answer': 'Your metabolism may slow down and you may feel tired. You might feel an urge to binge, especially on sugar-laden foods. Chronic dieting, in fact, can lead to an eating disorder.'},
#  {'question': 'prices of liposuction', 'answer': 'from $2,000 to $4,000.'},
#  {'question': 'what are the sounds of the heart caused by',
#   'answer': 'the heart valves opening and closing as they pump blood.'},
#  {'question': 'what is mrsa caused by',
#   'answer': 'Methicillin-resistant Staphylococcus aureus (MRSA) is a bacterium that causes infections in different parts of the body.'},
#  {'question': 'what does personality disorder mean',
#   'answer': 'personality disorder is a type of mental disorder in which you have a rigid and unhealthy pattern of thinking, functioning and behaving.'},
#  {'question': 'what is a stretch reflex',
#   'answer': 'a muscle contraction in response to stretching within the muscle.'},
#  {'question': 'where to find camellia oil',
#   'answer': 'oleic acid and vitamins A, B, D and E as well as nourishing Omega 3, 6 and 9.'}]

# %%
sample_external = df[['question', 'answer']].head(20).to_dict('records')
sample_external
# Out:
# [{'question': 'what disability is copd',
#   'answer': 'Chronic Obstructive Pulmonary Disease and Social Security Disability COPD, or chronic obstructive pulmonary disease is a series of lung diseases that damages your lungs, blocking airflow and affecting your ability to breathe.'},
#  {'question': 'what does folic acid do',
#   'answer': 'crucial for proper brain function and plays an important role in mental and emotional health.'},
#  {'question': 'the importance of minerals in diet',
#   'answer': 'Minerals are incredibly important for health and to prevent chronic disease.'},
#  {'question': 'triglycerides what are they',
#   'answer': 'A triglyceride is an ester derived from glycerol and three to four fatty acids.'},
#  {'question': 'what causes resorption of teeth',
#   'answer': 'trauma, periodontitis, orthodontic treatment, internal bleaching, cysts, tumors or stimuli from a necrotic dental pulp may cause tooth root resorption.'},
#  {'question': 'is the mitochondria a organelle or a function',
#   'answer': 'They are made of two membranes. The outer membrane covers the organelle and contains it like a skin. The inner membrane folds over many times and creates layered structures called cristae.'},
#  {'question': 'what counts are taken in urine', 'answer': '0-5 wbc/hpf'},
#  {'question': 'the ________ nerves regulate essential involuntary body functions',
#   'answer': 'Sympathetic'},
#  {'question': 'what is conjugated bilirubin',
#   'answer': 'formed in the liver when sugars are attached (conjugated) to bilirubin.'},
#  {'question': 'what does it mean if your chest feels heavy',
#   'answer': 'anxiety'},
#  {'question': 'cost of januvia', 'answer': '$190 a month'},
#  {'question': 'transgenic organisms what are they',
#   'answer': 'A transgenic organism is an organism which has been modified with genetic material from another species.'},
#  {'question': 'depressive personality disorder',
#   'answer': 'Depressive personality disorder is a psychiatric diagnosis that denotes a personality disorder with depressive features.'},
#  {'question': 'what do sensory neurons do',
#   'answer': 'Sensory neurons carry signals from the outer parts of your body (periphery) into the central nervous system.'},
#  {'question': 'what are all organism made up mostly', 'answer': 'Cells'},
#  {'question': 'what is a piebald dachshund',
#   'answer': 'A piebald dachshund puppy is born when two wieners with the recessive piebald gene breed together.'},
#  {'question': 'what causes savant syndrome',
#   'answer': 'Savant syndrome is a rare syndrome in which people with poor mental development or brain injury possess extraordinary mental skills which are difficult to explain scientifically.'},
#  {'question': 'effects of prolonged cell phone use',
#   'answer': 'associated with stress and sleep disturbances for women, whereas high mobile phone use was associated with sleep disturbances and symptoms of depression in men.'},
#  {'question': 'what is an ESR level on a blood test?',
#   'answer': 'Sed rate, or erythrocyte sedimentation rate (ESR), is a blood test that can reveal inflammatory activity in your body.'},
#  {'question': 'what is hiv/aids google',
#   'answer': 'the virus that causes acquired immune deficiency syndrome (AIDS).'}]

# %% [markdown]
# ## Checking for common questions between the examples above

# %%
set(train['question'].head(20)) & set(df['question'].head(20))
# Out:
# set()

# %%
set(test['question'].head(20)) & set(df['question'].head(20))
# Out:
# set()
